# %%
# Forecast Competitor's Sales

# Import Libraries for data wrangling and machine learning 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Iterable
import itertools
import seaborn as sns
from sklearn.utils import indexable
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import random
from keras.models import Sequential
from sklearn.utils import shuffle
from keras.layers import Dense
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler
from graphviz import *
from copy import *
import datetime
from datetime import date, timedelta, datetime
from sklearn.metrics import r2_score, mean_squared_error,  mean_absolute_error, median_absolute_error
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
#%matplotlib inline 
## Run at end of script
#conn.close()


# Load Holiday Data

# Load Holiday Data
df0 = pd.read_excel('C:/Users/e351722/OneDrive - EDP/REN_prediction/holidays_ES.xlsx', sheet_name='Sheet1', converters={'Unnamed1':str, 
                                                                                        'Date':str,
                                                                                        'Weekday':str,
                                                                                        'Holiday':str,
                                                                                        'Holiday_type':str,
                                                                            
                                                                                        'Unnamed2':str})
df0 = df0.dropna()


df0['date'] = pd.DatetimeIndex(df0['Date'])
df0['dayofweek'] = df0['date'].apply(lambda x: x.dayofweek)
df0['dayofyear'] = df0['date'].apply(lambda x: x.dayofyear)


# Load Data
df = pd.read_pickle('C:/Users/e351722/OneDrive - EDP/Competition/prices_demand_pcb.pkl')
df.tail()




df['date'] = pd.DatetimeIndex(df['DATA'])
df['day'] = df['date'].apply(lambda x: x.day)
df['dayofweek'] = df['date'].apply(lambda x: x.dayofweek)
df['dayofyear'] = df['date'].apply(lambda x: x.dayofyear)
#df['month'] = df['date'].apply(lambda x: x.month)
#df['year'] = df['date'].apply(lambda x: x.year)
df['holiday'] = 0
df['holiday'][(df['dayofweek'].isin([5,6])) | (df['dayofyear'].isin(set(df0.dayofyear)))] = 1
df = df.drop(['dayofyear'], axis = 1)



# drop low correlated variables
df_new = df.drop(columns=['DATA', 'date'], axis=1) 
a=np.abs(df_new.corr().COMPETITION_COMPRAS)<.1
dropvariables = df.fillna(df.mean()).corr()[a==True].index[:-1]
df=df.drop(df[dropvariables[:-1]],axis=1)

# Set Dates for Training and Testing splits

pred_date_END = np.max(df.DATA)-timedelta(1) # PRECO_ES_1fut is undefined for the last day, so we test on max(date)-1

pred_date_START =  pred_date_END  - timedelta(7) # number of days for back-testing prediction, 0 means only the last day is used
                                                 # I recommend to use 7 when prototyping, and 0 for production
last_train_date = pred_date_START - timedelta(1) # All the data available minus the last day will be used for training

first_train_date =   pred_date_END - timedelta(120) # 395 days of historical data used. More days does not improve prediction.


# Eliminate NA's from Target Variable
df['COMPETITION_COMPRAS'] = df.COMPETITION_COMPRAS.fillna(0).replace(np.inf, 0)
# Create Y(t+1), the variable we want to predict
df['COMPETITION_COMPRAS_1fut']=df.groupby([ 'HORA'])['COMPETITION_COMPRAS'].shift(-1)



# # Train/Test Split


# Split train and test data according to date ranges set above

train = df[(df.date >= first_train_date) & (df.date <= last_train_date)].drop(['DATA'],1)

train = train.fillna(method='ffill')
train = train.fillna(train.mean())

df_test = df
df_test = df_test.fillna(method='ffill')
df_test = df_test.fillna(df_test.mean())

test = df_test[(df_test.date >= pred_date_START) & (df_test.date <= pred_date_END)].drop(['DATA'],1)

prediction_set =  df_test[(df_test.date >= pred_date_END+timedelta(1)) & (df_test.date <= pred_date_END+timedelta(1))].drop(['DATA'],1)

#train = pd.concat([train.reset_index(), pd.DataFrame(train_pca)], axis=1)
#test = pd.concat([test.reset_index(), pd.DataFrame(test_pca)], axis=1)
#prediction_set = pd.concat([prediction_set.reset_index(), pd.DataFrame(prediction_pca)], axis=1)

train = train.reset_index(drop=True)
test = test.reset_index(drop=True)
prediction_set=prediction_set.reset_index(drop=True)



X_test, y_test = [test.drop(['date', 'COMPETITION_COMPRAS_1fut'],1), test['COMPETITION_COMPRAS_1fut']]
X_pred = prediction_set.drop(['date', 'COMPETITION_COMPRAS_1fut'],1)

X_train, y_train = [train.drop(['date', 'COMPETITION_COMPRAS_1fut'],1), train['COMPETITION_COMPRAS_1fut']]

# Normalze variables, Final Preprocessing Step, needed for Neural Networks
# we create sets x_train_c, x_test_c, and x_pred_c by copying X_train and X_test and then normalizing the copies.

x_train_c= deepcopy(X_train)
x_test_c = deepcopy(X_test)
x_pred_c = deepcopy(X_pred)

from sklearn import preprocessing

# Normalize Training Data 
train_norm = x_train_c[x_train_c.columns[:]]
test_norm = x_test_c[x_test_c.columns[:]]
pred_norm = x_pred_c[x_pred_c.columns[:]]

std_scale = preprocessing.StandardScaler().fit(train_norm)
x_train_norm = std_scale.transform(train_norm)
#Converting numpy array to dataframe
training_norm_col = pd.DataFrame(x_train_norm, index=train_norm.index, columns=train_norm.columns) 
x_train_c.update(training_norm_col)

# Normalize Testing Data by using mean and SD of training set
x_test_norm = std_scale.transform(test_norm)
testing_norm_col = pd.DataFrame(x_test_norm, index=test_norm.index, columns=test_norm.columns) 
x_test_c.update(testing_norm_col)

# Normalize Prediction Data by using mean and SD of training set
x_pred_norm = std_scale.transform(pred_norm)
pred_norm_col = pd.DataFrame(x_pred_norm, index=pred_norm.index, columns=pred_norm.columns) 
x_pred_c.update(pred_norm_col)



# Define MAPE evaluation metric
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Out:
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:142: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by StandardScaler.
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:148: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by StandardScaler.
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:153: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by StandardScaler.

# %%
# Build XGBoost Model

def prediction_xgboost(x_train, y_train, x_test, y_test):
    """
    Machine learning implementation - XGBoost algorithm.

    :param x_train: Predictors train.
    :param y_train: Response variable train.
    :param x_test: Predictors test.
    :param y_test: Response variable test.
    :return: The XGBoost model.
    """
    # Define the splits.
    # idxs = np.arange(N)
    cv_splits = 5
    clf = xgb.XGBRegressor(objective="reg:linear")
    # Defining the grid search
    
    
    # ---------------------------------------------------without pca-----------------------------------------------------
#{'colsample_bylevel': 1, 'colsample_bytree': 0.7, 'eval_metric': 'mae', 'gamma': 0.03, 'gpu_id': 0, 'learning_rate': 0.1,
 #'max_bin': 256, 'n_estimators': 400,'predictor': 'gpu_predictor', 'reg_alpha': 0.01, 'reg_lambda': 1, 'subsample': 0.8,
 #'tree_method': 'gpu_hist'}
    # --------------------------------------------------with pca-------------------
#{'colsample_bylevel': 1, 'colsample_bytree': 0.7, 'eval_metric': 'mae', 'gamma': 0.01, 'gpu_id': 0, 'learning_rate': 0.1,
#'max_bin': 256, 'n_estimators': 500, 'predictor': 'gpu_predictor', 'reg_alpha': 0.01,'reg_lambda': 1, 'subsample': 0.8,
#'tree_method': 'gpu_hist'earning_rate': 0.03, 'subsample': 0.8, 'colsample_bylevel': 1, 'colsample_bytree': 0.7, 'max_depth': 15}
    # --------------------------------------------------with pca feat.sel.---------------------------------------------------------
#{'colsample_bylevel': 1, 'colsample_bytree': 0.7, 'eval_metric': 'mae', 'gamma': 0.01, 'gpu_id': 0, 'learning_rate': 0.1,
# 'max_bin': 256, 'n_estimators': 500, 'predictor': 'gpu_predictor', 'reg_alpha': 0.01,'reg_lambda': 1, 'subsample': 0.8, 
# 'tree_method': 'gpu_hist'}
# --------------------------------------------------.---------------------------------------------------------
    
    
  #  , 'gpu_id':[0], 'max_bin':[16],
  #                'predictor': ['gpu_predictor'], 'tree_method': ['gpu_hist'], 'eval_metric': ['mae']
    
    
    param_grid = {'colsample_bylevel': [1], 'colsample_bytree': [0.7],
                  'gamma': [0.03], 'learning_rate': [0.1],
                  'n_estimators': [400], 'reg_alpha': [0.01],
                  'reg_lambda': [1], 'subsample': [0.8]
   
                  }

    print('    Model training')

    tree_grid = GridSearchCV(estimator=clf, param_grid=param_grid,
                             iid=False, refit=True, cv=cv_splits, verbose=5, n_jobs = -1) #, scoring='neg_mean_squared_error'
    tree = tree_grid.fit(x_train, y_train)
    

    print(tree.best_params_)
    tree_predict = tree.predict(x_test)
    features = tree.estimator.fit(x_train, y_train).feature_importances_
    feature_imp_df = pd.DataFrame({'Importance': features},
                                  index=x_test.columns.ravel()).sort_values('Importance', ascending=False)

    print('\n', 'r2_score:', r2_score(y_test, tree_predict), '\n',
          'mean_squared_error', mean_squared_error(y_test, tree_predict), '\n',
 #         'mean_absolute_error', mean_absolute_error(y_test, tree_predict), '\n',
          'mean_absolute_percentage_error', mean_absolute_percentage_error(y_test, tree_predict), '\n')
    MAP_error = mean_absolute_percentage_error(y_test, tree_predict)
    
    print('\n')
    

    return tree_predict, y_test, tree, MAP_error, feature_imp_df


def model_plot(x, y, tree_predict):

    plt.figure()
    plt.scatter( y, x['COMPETITION_COMPRAS'], c="cornflowerblue", label="d")
    plt.scatter( y, tree_predict, color="darkorange", label="XGBoost", linewidth=2)
    plt.xlabel("Actual D+1 Energy")
    plt.ylabel("Predicted D+1 Energy")
    plt.title("Decision Tree Regression")
    plt.legend()
    plt.show()
    return None


def metric_model_plot(y_test, tree_predict):
    max_x = max(y_test)
    min_x = min(y_test)
    max_y = max(tree_predict)
    min_y = min(tree_predict)
    plt.figure()
    plt.scatter(y_test, tree_predict, c="darkorange", label="test data")
    plt.xlim(min_x, max_x)
    plt.ylim(min_y, max_y)
    plt.plot([min_x, max_x], [min_x, max_x], 'k--')

    plt.xlabel("Actual D+1 Energy")
    plt.ylabel("Predicted D+1 Energy")
    plt.title("Decision Tree")
    plt.legend()
    #plt.savefig('fig.png')  # save the figure to file
    plt.show()
    
    plt.figure()
    plt.plot(y_test, c = 'black', label = 'Actual')
    plt.plot(tree_predict, c = 'darkorange', label = 'Predicted')
    plt.xlabel("Predicted vs. Actual Energy")
    plt.ylabel("Price")
    plt.title("Hour")
    plt.legend()
    plt.show()
    return None


# In[49]:


from sklearn.metrics import r2_score, mean_squared_error,  mean_absolute_error, median_absolute_error
import matplotlib.pyplot as plt
predicted1, y_test1, tree1, MAP_error1, feature_imp_df = prediction_xgboost(X_train, y_train, X_test, y_test)

# Generate Day-ahead prediction
tree1_prediction = list(tree1.predict(X_pred))

# Make plots
import datetime

test_dates = df['DATA'].tail(len(y_test1)).reset_index(drop=True)
test_hours = df['HORA'].tail(len(y_test1)).reset_index(drop=True)

hora = []
combined = []
for i in range(0,len(y_test1)):
    #hora.append(datetime.time(test_hours[i]-1,0))
    dt = test_dates[i]
    combined.append(dt.combine(dt, datetime.time(test_hours[i]-1,0)))
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
#     Model training
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    6.2s remaining:    9.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    9.8s finished
# {'colsample_bylevel': 1, 'colsample_bytree': 0.7, 'gamma': 0.03, 'learning_rate': 0.1, 'n_estimators': 400, 'reg_alpha': 0.01, 'reg_lambda': 1, 'subsample': 0.8}
#
#  r2_score: 0.9449589732060552
#  mean_squared_error 14415.95283008928
#  mean_absolute_percentage_error 3.156838931600715

# %%
# Visualize Results
print('\n', 'mean_absolute_percentage_error', MAP_error1, '\n')

# Test vs Actual
plt.figure(figsize=(15, 7))

plt.plot(combined, y_test1)
plt.plot(combined, predicted1)
plt.legend(['Test Data', 'XGBoost'])
plt.title('Competition Compras')
plt.ylabel('Energy (MWh)')
plt.xlabel('Date')

# Feature Importance
n=30
plt.figure(figsize=(15, 10))
feature_imp_df.head(n).plot(kind='bar')
plt.grid(True, axis='y')
plt.hlines(y=0, xmin=0, xmax=n, linestyles='dashed')
plt.title('XGBoost Feature Importance');
# Out:
#  mean_absolute_percentage_error 3.156838931600715

# %%
# Remove Least Used Features
a = feature_imp_df<= 0.005
b = a[a.Importance==True]
dropvariables = b.index
df=df.drop(df[dropvariables],axis=1)

train = df[(df.date >= first_train_date) & (df.date <= last_train_date)].drop(['DATA'],1)

train = train.fillna(method='ffill')
train = train.fillna(train.mean())

df_test = df
df_test = df_test.fillna(method='ffill')
df_test = df_test.fillna(df_test.mean())

test = df_test[(df_test.date >= pred_date_START) & (df_test.date <= pred_date_END)].drop(['DATA'],1)

prediction_set =  df_test[(df_test.date >= pred_date_END+timedelta(1)) & (df_test.date <= pred_date_END+timedelta(1))].drop(['DATA'],1)


train = train.reset_index(drop=True)
test = test.reset_index(drop=True)
prediction_set=prediction_set.reset_index(drop=True)


X_test, y_test = [test.drop(['date', 'COMPETITION_COMPRAS_1fut'],1), test['COMPETITION_COMPRAS_1fut']]
X_pred = prediction_set.drop(['date', 'COMPETITION_COMPRAS_1fut'],1)

X_train, y_train = [train.drop(['date', 'COMPETITION_COMPRAS_1fut'],1), train['COMPETITION_COMPRAS_1fut']]

# Normalze variables, Final Preprocessing Step, needed for Neural Networks
# we create sets x_train_c, x_test_c, and x_pred_c by copying X_train and X_test and then normalizing the copies.

x_train_c= deepcopy(X_train)
x_test_c = deepcopy(X_test)
x_pred_c = deepcopy(X_pred)

from sklearn import preprocessing

# Normalize Training Data 
train_norm = x_train_c[x_train_c.columns[:]]
test_norm = x_test_c[x_test_c.columns[:]]
pred_norm = x_pred_c[x_pred_c.columns[:]]

std_scale = preprocessing.StandardScaler().fit(train_norm)
x_train_norm = std_scale.transform(train_norm)
#Converting numpy array to dataframe
training_norm_col = pd.DataFrame(x_train_norm, index=train_norm.index, columns=train_norm.columns) 
x_train_c.update(training_norm_col)

# Normalize Testing Data by using mean and SD of training set
x_test_norm = std_scale.transform(test_norm)
testing_norm_col = pd.DataFrame(x_test_norm, index=test_norm.index, columns=test_norm.columns) 
x_test_c.update(testing_norm_col)

# Normalize Prediction Data by using mean and SD of training set
x_pred_norm = std_scale.transform(pred_norm)
pred_norm_col = pd.DataFrame(x_pred_norm, index=pred_norm.index, columns=pred_norm.columns) 
x_pred_c.update(pred_norm_col)
# Out:
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:46: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by StandardScaler.
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:52: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by StandardScaler.
# C:\Users\e351722\AppData\Local\Continuum\anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:57: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by StandardScaler.

# %%
def keras_dnn(x_train, y_train, x_test, y_test):

    '''Using normalized data to predict day ahead prices'''
    import pandas as pd
    #from sklearn.cross_validation import train_test_split
    from IPython import display
    from matplotlib import cm
    from matplotlib import gridspec
    from matplotlib import pyplot as plt
    import numpy as np
    import pandas as pd
    from sklearn import metrics
    import tensorflow as tf
    from tensorflow.python.data import Dataset
    import keras
    from keras.utils import to_categorical
    from keras import models
    from keras import layers
    import math
    import matplotlib.pyplot as plt
    #df = pd.read_csv('covtype.csv')


    hl_scaling = 4
    input_layer = np.shape(x_train)[1]
    output_layer = 1
    middle_hidden_layer = round((np.shape(x_train)[0])/(hl_scaling*(np.shape(x_train)[1]+output_layer)))

    #x_train, x_test, y_train, y_test = train_test_split(x, y , train_size = 0.7, random_state =  90)
    #'''As y variable is multi class categorical variable, hence using softmax as activation function and sparse-categorical cross entropy as loss function.'''
    model = keras.Sequential([
     keras.layers.Dense(input_layer, kernel_initializer='normal', activation=tf.nn.relu,                  
     input_shape=(x_train.shape[1],)),
     #keras.layers.Dropout(0.8, noise_shape=None, seed=None),

     keras.layers.Dense(middle_hidden_layer,  kernel_initializer='normal', activation=tf.nn.relu),
  #   keras.layers.Dropout(0.8, noise_shape=None, seed=None),
  #   keras.layers.Dense(round(middle_hidden_layer/2),  kernel_initializer='normal', activation=tf.nn.relu),
        
  #   keras.layers.Dense(round(middle_hidden_layer/4),  kernel_initializer='normal', activation=tf.nn.relu),

     keras.layers.Dense(output_layer, activation='linear'),


     #keras.layers.Dense(1, activation=  'softmax')
     ])
    
    model.compile(optimizer='adam',
              loss='mean_absolute_percentage_error',
              metrics=['mean_absolute_percentage_error'])
    history1 = model.fit(
     x_train, y_train,
     epochs= 100, batch_size = 100,
     validation_data = (x_test, y_test))

    return history1, model

#make plots
def plot_history(history1):
 plt.figure()
 plt.xlabel('Epoch')
 plt.ylabel('Mean Absolute Percent Error [1000$]')
 plt.plot(history1.epoch, np.array(history1.history['mean_absolute_percentage_error']),
 label='Train MAPE')
 plt.plot(history1.epoch, np.array(history1.history['val_mean_absolute_percentage_error']),
 label = 'Val MAPE')
 plt.legend()

[history1, model] = keras_dnn(x_train_c, y_train, x_test_c, y_test)

plot_history(history1)

# Plot Back-testing prediction
predictedkeras = model.predict(x_test_c)
plt.figure()

MAP_error3 = mean_absolute_percentage_error(predictedkeras.flatten(), y_test)


#plt.plot(ynew)
#plt.plot(y_test.reset_index(drop=True))
#plt.show()

#plt.figure()
#plt.scatter(y_test,pd.DataFrame(ynew))
#max_x = max(y_test)
#min_x = min(y_test)
#max_y = max(ynew)
#min_y = min(ynew)
#plt.xlim(min_x, max_x)
#plt.ylim(min_y, max_y)
#plt.plot([min_x, max_x], [min_x, max_x], 'k--')
#plt.show()

print(MAP_error3)

lstm_prediction = model.predict(x_pred_c.tail(24)).flatten()
#plt.figure()
#plt.plot(tree5_prediction.flatten())
#plt.show()
# Out:
# Train on 2712 samples, validate on 192 samples
# Epoch 1/100
# 2712/2712 [==============================] - 2s 689us/step - loss: 99.9908 - mean_absolute_percentage_error: 99.9908 - val_loss: 99.9697 - val_mean_absolute_percentage_error: 99.9697
# Epoch 2/100
# 2712/2712 [==============================] - 0s 38us/step - loss: 99.9343 - mean_absolute_percentage_error: 99.9343 - val_loss: 99.8657 - val_mean_absolute_percentage_error: 99.8657
# Epoch 3/100
# 2712/2712 [==============================] - 0s 38us/step - loss: 99.7455 - mean_absolute_percentage_error: 99.7455 - val_loss: 99.5794 - val_mean_absolute_percentage_error: 99.5794
# Epoch 4/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 99.2973 - mean_absolute_percentage_error: 99.2973 - val_loss: 98.9747 - val_mean_absolute_percentage_error: 98.9747
# Epoch 5/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 98.4484 - mean_absolute_percentage_error: 98.4484 - val_loss: 97.9138 - val_mean_absolute_percentage_error: 97.9138
# Epoch 6/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 97.0786 - mean_absolute_percentage_error: 97.0786 - val_loss: 96.2723 - val_mean_absolute_percentage_error: 96.2723
# Epoch 7/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 95.0202 - mean_absolute_percentage_error: 95.0202 - val_loss: 93.9352 - val_mean_absolute_percentage_error: 93.9352
# Epoch 8/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 92.2044 - mean_absolute_percentage_error: 92.2044 - val_loss: 90.7710 - val_mean_absolute_percentage_error: 90.7710
# Epoch 9/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 88.4395 - mean_absolute_percentage_error: 88.4395 - val_loss: 86.6936 - val_mean_absolute_percentage_error: 86.6936
# Epoch 10/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 83.6645 - mean_absolute_percentage_error: 83.6645 - val_loss: 81.5277 - val_mean_absolute_percentage_error: 81.5277
# Epoch 11/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 77.6905 - mean_absolute_percentage_error: 77.6905 - val_loss: 75.1620 - val_mean_absolute_percentage_error: 75.1620
# Epoch 12/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 70.9392 - mean_absolute_percentage_error: 70.9392 - val_loss: 67.7976 - val_mean_absolute_percentage_error: 67.7976
# Epoch 13/100
# 2712/2712 [==============================] - 0s 40us/step - loss: 64.8816 - mean_absolute_percentage_error: 64.8816 - val_loss: 60.0374 - val_mean_absolute_percentage_error: 60.0374
# Epoch 14/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 59.8552 - mean_absolute_percentage_error: 59.8552 - val_loss: 52.1888 - val_mean_absolute_percentage_error: 52.1888
# Epoch 15/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 55.3380 - mean_absolute_percentage_error: 55.3380 - val_loss: 44.5259 - val_mean_absolute_percentage_error: 44.5259
# Epoch 16/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 51.8282 - mean_absolute_percentage_error: 51.8282 - val_loss: 38.0805 - val_mean_absolute_percentage_error: 38.0805
# Epoch 17/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 49.4656 - mean_absolute_percentage_error: 49.4656 - val_loss: 34.7365 - val_mean_absolute_percentage_error: 34.7365
# Epoch 18/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 47.9069 - mean_absolute_percentage_error: 47.9069 - val_loss: 34.0314 - val_mean_absolute_percentage_error: 34.0314
# Epoch 19/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 46.7538 - mean_absolute_percentage_error: 46.7538 - val_loss: 34.5090 - val_mean_absolute_percentage_error: 34.5090
# Epoch 20/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 45.8306 - mean_absolute_percentage_error: 45.8306 - val_loss: 35.2280 - val_mean_absolute_percentage_error: 35.2280
# Epoch 21/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 45.1400 - mean_absolute_percentage_error: 45.1400 - val_loss: 35.8930 - val_mean_absolute_percentage_error: 35.8930
# Epoch 22/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 44.5382 - mean_absolute_percentage_error: 44.5382 - val_loss: 36.2814 - val_mean_absolute_percentage_error: 36.2814
# Epoch 23/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 43.9832 - mean_absolute_percentage_error: 43.9832 - val_loss: 36.6681 - val_mean_absolute_percentage_error: 36.6681
# Epoch 24/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 43.4796 - mean_absolute_percentage_error: 43.4796 - val_loss: 36.9518 - val_mean_absolute_percentage_error: 36.9518
# Epoch 25/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 43.0020 - mean_absolute_percentage_error: 43.0020 - val_loss: 37.2720 - val_mean_absolute_percentage_error: 37.2720
# Epoch 26/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 42.5601 - mean_absolute_percentage_error: 42.5601 - val_loss: 36.9914 - val_mean_absolute_percentage_error: 36.9914
# Epoch 27/100
# 2712/2712 [==============================] - 0s 38us/step - loss: 42.1199 - mean_absolute_percentage_error: 42.1199 - val_loss: 36.9523 - val_mean_absolute_percentage_error: 36.9523
# Epoch 28/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 41.6897 - mean_absolute_percentage_error: 41.6897 - val_loss: 36.8318 - val_mean_absolute_percentage_error: 36.8318
# Epoch 29/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 41.2622 - mean_absolute_percentage_error: 41.2622 - val_loss: 36.5525 - val_mean_absolute_percentage_error: 36.5525
# Epoch 30/100
# 2712/2712 [==============================] - 0s 38us/step - loss: 40.8374 - mean_absolute_percentage_error: 40.8374 - val_loss: 36.5559 - val_mean_absolute_percentage_error: 36.5559
# Epoch 31/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 40.4151 - mean_absolute_percentage_error: 40.4151 - val_loss: 36.0843 - val_mean_absolute_percentage_error: 36.0843
# Epoch 32/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 39.9776 - mean_absolute_percentage_error: 39.9776 - val_loss: 35.8817 - val_mean_absolute_percentage_error: 35.8817
# Epoch 33/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 39.5256 - mean_absolute_percentage_error: 39.5256 - val_loss: 35.6126 - val_mean_absolute_percentage_error: 35.6126
# Epoch 34/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 39.0620 - mean_absolute_percentage_error: 39.0620 - val_loss: 35.1400 - val_mean_absolute_percentage_error: 35.1400
# Epoch 35/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 38.5694 - mean_absolute_percentage_error: 38.5694 - val_loss: 34.6894 - val_mean_absolute_percentage_error: 34.6894
# Epoch 36/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 38.0789 - mean_absolute_percentage_error: 38.0789 - val_loss: 34.3759 - val_mean_absolute_percentage_error: 34.3759
# Epoch 37/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 37.5722 - mean_absolute_percentage_error: 37.5722 - val_loss: 33.9917 - val_mean_absolute_percentage_error: 33.9917
# Epoch 38/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 37.0540 - mean_absolute_percentage_error: 37.0540 - val_loss: 33.8226 - val_mean_absolute_percentage_error: 33.8226
# Epoch 39/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 36.5110 - mean_absolute_percentage_error: 36.5110 - val_loss: 33.3978 - val_mean_absolute_percentage_error: 33.3978
# Epoch 40/100
# 2712/2712 [==============================] - 0s 38us/step - loss: 35.9548 - mean_absolute_percentage_error: 35.9548 - val_loss: 32.8863 - val_mean_absolute_percentage_error: 32.8863
# Epoch 41/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 35.3616 - mean_absolute_percentage_error: 35.3616 - val_loss: 32.2836 - val_mean_absolute_percentage_error: 32.2836
# Epoch 42/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 34.7371 - mean_absolute_percentage_error: 34.7371 - val_loss: 31.5918 - val_mean_absolute_percentage_error: 31.5918
# Epoch 43/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 34.0836 - mean_absolute_percentage_error: 34.0836 - val_loss: 31.1210 - val_mean_absolute_percentage_error: 31.1210
# Epoch 44/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 33.3751 - mean_absolute_percentage_error: 33.3751 - val_loss: 30.5249 - val_mean_absolute_percentage_error: 30.5249
# Epoch 45/100
# 2712/2712 [==============================] - 0s 40us/step - loss: 32.6313 - mean_absolute_percentage_error: 32.6313 - val_loss: 29.5181 - val_mean_absolute_percentage_error: 29.5181
# Epoch 46/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 31.8383 - mean_absolute_percentage_error: 31.8383 - val_loss: 28.8552 - val_mean_absolute_percentage_error: 28.8552
# Epoch 47/100
# 2712/2712 [==============================] - 0s 38us/step - loss: 30.9738 - mean_absolute_percentage_error: 30.9738 - val_loss: 28.0698 - val_mean_absolute_percentage_error: 28.0698
# Epoch 48/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 30.0385 - mean_absolute_percentage_error: 30.0385 - val_loss: 27.4570 - val_mean_absolute_percentage_error: 27.4570
# Epoch 49/100
# 2712/2712 [==============================] - 0s 47us/step - loss: 29.0166 - mean_absolute_percentage_error: 29.0166 - val_loss: 26.6094 - val_mean_absolute_percentage_error: 26.6094
# Epoch 50/100
# 2712/2712 [==============================] - 0s 40us/step - loss: 27.9410 - mean_absolute_percentage_error: 27.9410 - val_loss: 25.6357 - val_mean_absolute_percentage_error: 25.6357
# Epoch 51/100
# 2712/2712 [==============================] - 0s 34us/step - loss: 26.8693 - mean_absolute_percentage_error: 26.8693 - val_loss: 24.6916 - val_mean_absolute_percentage_error: 24.6916
# Epoch 52/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 25.8301 - mean_absolute_percentage_error: 25.8301 - val_loss: 23.9867 - val_mean_absolute_percentage_error: 23.9867
# Epoch 53/100
# 2712/2712 [==============================] - 0s 40us/step - loss: 24.8547 - mean_absolute_percentage_error: 24.8547 - val_loss: 23.4575 - val_mean_absolute_percentage_error: 23.4575
# Epoch 54/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 23.9493 - mean_absolute_percentage_error: 23.9493 - val_loss: 22.5551 - val_mean_absolute_percentage_error: 22.5551
# Epoch 55/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 23.0676 - mean_absolute_percentage_error: 23.0676 - val_loss: 21.8868 - val_mean_absolute_percentage_error: 21.8868
# Epoch 56/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 22.2404 - mean_absolute_percentage_error: 22.2404 - val_loss: 20.8346 - val_mean_absolute_percentage_error: 20.8346
# Epoch 57/100
# 2712/2712 [==============================] - 0s 34us/step - loss: 21.4539 - mean_absolute_percentage_error: 21.4539 - val_loss: 20.2788 - val_mean_absolute_percentage_error: 20.2788
# Epoch 58/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 20.7411 - mean_absolute_percentage_error: 20.7411 - val_loss: 19.3496 - val_mean_absolute_percentage_error: 19.3496
# Epoch 59/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 20.1001 - mean_absolute_percentage_error: 20.1001 - val_loss: 19.1057 - val_mean_absolute_percentage_error: 19.1057
# Epoch 60/100
# 2712/2712 [==============================] - 0s 34us/step - loss: 19.4670 - mean_absolute_percentage_error: 19.4670 - val_loss: 18.5166 - val_mean_absolute_percentage_error: 18.5166
# Epoch 61/100
# 2712/2712 [==============================] - 0s 34us/step - loss: 18.9158 - mean_absolute_percentage_error: 18.9158 - val_loss: 17.8227 - val_mean_absolute_percentage_error: 17.8227
# Epoch 62/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 18.3882 - mean_absolute_percentage_error: 18.3882 - val_loss: 17.5217 - val_mean_absolute_percentage_error: 17.5217
# Epoch 63/100
# 2712/2712 [==============================] - 0s 34us/step - loss: 17.9095 - mean_absolute_percentage_error: 17.9095 - val_loss: 16.9356 - val_mean_absolute_percentage_error: 16.9356
# Epoch 64/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 17.4359 - mean_absolute_percentage_error: 17.4359 - val_loss: 16.7349 - val_mean_absolute_percentage_error: 16.7349
# Epoch 65/100
# 2712/2712 [==============================] - 0s 34us/step - loss: 16.9763 - mean_absolute_percentage_error: 16.9763 - val_loss: 16.1412 - val_mean_absolute_percentage_error: 16.1412
# Epoch 66/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 16.5470 - mean_absolute_percentage_error: 16.5470 - val_loss: 15.9600 - val_mean_absolute_percentage_error: 15.9600
# Epoch 67/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 16.1328 - mean_absolute_percentage_error: 16.1328 - val_loss: 15.7062 - val_mean_absolute_percentage_error: 15.7062
# Epoch 68/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 15.7287 - mean_absolute_percentage_error: 15.7287 - val_loss: 15.4415 - val_mean_absolute_percentage_error: 15.4415
# Epoch 69/100
# 2712/2712 [==============================] - 0s 38us/step - loss: 15.3131 - mean_absolute_percentage_error: 15.3131 - val_loss: 14.9988 - val_mean_absolute_percentage_error: 14.9988
# Epoch 70/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 14.9234 - mean_absolute_percentage_error: 14.9234 - val_loss: 14.6678 - val_mean_absolute_percentage_error: 14.6678
# Epoch 71/100
# 2712/2712 [==============================] - 0s 34us/step - loss: 14.5172 - mean_absolute_percentage_error: 14.5172 - val_loss: 14.5611 - val_mean_absolute_percentage_error: 14.5611
# Epoch 72/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 14.1217 - mean_absolute_percentage_error: 14.1217 - val_loss: 14.4891 - val_mean_absolute_percentage_error: 14.4891
# Epoch 73/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 13.7501 - mean_absolute_percentage_error: 13.7501 - val_loss: 13.8552 - val_mean_absolute_percentage_error: 13.8552
# Epoch 74/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 13.3963 - mean_absolute_percentage_error: 13.3963 - val_loss: 13.6204 - val_mean_absolute_percentage_error: 13.6204
# Epoch 75/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 13.0423 - mean_absolute_percentage_error: 13.0423 - val_loss: 13.3575 - val_mean_absolute_percentage_error: 13.3575
# Epoch 76/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 12.7000 - mean_absolute_percentage_error: 12.7000 - val_loss: 13.1348 - val_mean_absolute_percentage_error: 13.1348
# Epoch 77/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 12.3738 - mean_absolute_percentage_error: 12.3738 - val_loss: 13.1759 - val_mean_absolute_percentage_error: 13.1759
# Epoch 78/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 12.0539 - mean_absolute_percentage_error: 12.0539 - val_loss: 12.5308 - val_mean_absolute_percentage_error: 12.5308
# Epoch 79/100
# 2712/2712 [==============================] - 0s 36us/step - loss: 11.7379 - mean_absolute_percentage_error: 11.7379 - val_loss: 12.5147 - val_mean_absolute_percentage_error: 12.5147
# Epoch 80/100
# 2712/2712 [==============================] - 0s 40us/step - loss: 11.4168 - mean_absolute_percentage_error: 11.4168 - val_loss: 12.1120 - val_mean_absolute_percentage_error: 12.1120
# Epoch 81/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 11.1145 - mean_absolute_percentage_error: 11.1145 - val_loss: 11.7532 - val_mean_absolute_percentage_error: 11.7532
# Epoch 82/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 10.8303 - mean_absolute_percentage_error: 10.8303 - val_loss: 11.4124 - val_mean_absolute_percentage_error: 11.4124
# Epoch 83/100
# 2712/2712 [==============================] - 0s 39us/step - loss: 10.5610 - mean_absolute_percentage_error: 10.5610 - val_loss: 11.0709 - val_mean_absolute_percentage_error: 11.0709
# Epoch 84/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 10.2782 - mean_absolute_percentage_error: 10.2782 - val_loss: 10.9974 - val_mean_absolute_percentage_error: 10.9974
# Epoch 85/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 10.0250 - mean_absolute_percentage_error: 10.0250 - val_loss: 10.5682 - val_mean_absolute_percentage_error: 10.5682
# Epoch 86/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 9.7757 - mean_absolute_percentage_error: 9.7757 - val_loss: 10.6314 - val_mean_absolute_percentage_error: 10.6314
# Epoch 87/100
# 2712/2712 [==============================] - 0s 38us/step - loss: 9.5267 - mean_absolute_percentage_error: 9.5267 - val_loss: 10.4176 - val_mean_absolute_percentage_error: 10.4176
# Epoch 88/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 9.2948 - mean_absolute_percentage_error: 9.2948 - val_loss: 10.0220 - val_mean_absolute_percentage_error: 10.0220
# Epoch 89/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 9.0715 - mean_absolute_percentage_error: 9.0715 - val_loss: 9.9706 - val_mean_absolute_percentage_error: 9.9706
# Epoch 90/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 8.8560 - mean_absolute_percentage_error: 8.8560 - val_loss: 9.9076 - val_mean_absolute_percentage_error: 9.9076
# Epoch 91/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 8.6386 - mean_absolute_percentage_error: 8.6386 - val_loss: 9.6288 - val_mean_absolute_percentage_error: 9.6288
# Epoch 92/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 8.4316 - mean_absolute_percentage_error: 8.4316 - val_loss: 9.4655 - val_mean_absolute_percentage_error: 9.4655
# Epoch 93/100
# 2712/2712 [==============================] - 0s 38us/step - loss: 8.2313 - mean_absolute_percentage_error: 8.2313 - val_loss: 9.0680 - val_mean_absolute_percentage_error: 9.0680
# Epoch 94/100
# 2712/2712 [==============================] - 0s 35us/step - loss: 8.0408 - mean_absolute_percentage_error: 8.0408 - val_loss: 8.8655 - val_mean_absolute_percentage_error: 8.8655
# Epoch 95/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 7.8523 - mean_absolute_percentage_error: 7.8523 - val_loss: 9.0003 - val_mean_absolute_percentage_error: 9.0003
# Epoch 96/100
# 2712/2712 [==============================] - 0s 49us/step - loss: 7.6716 - mean_absolute_percentage_error: 7.6716 - val_loss: 8.5151 - val_mean_absolute_percentage_error: 8.5151
# Epoch 97/100
# 2712/2712 [==============================] - 0s 48us/step - loss: 7.4981 - mean_absolute_percentage_error: 7.4981 - val_loss: 8.5476 - val_mean_absolute_percentage_error: 8.5476
# Epoch 98/100
# 2712/2712 [==============================] - 0s 40us/step - loss: 7.3243 - mean_absolute_percentage_error: 7.3243 - val_loss: 8.4411 - val_mean_absolute_percentage_error: 8.4411
# Epoch 99/100
# 2712/2712 [==============================] - 0s 37us/step - loss: 7.1612 - mean_absolute_percentage_error: 7.1612 - val_loss: 8.2912 - val_mean_absolute_percentage_error: 8.2912
# Epoch 100/100
# 2712/2712 [==============================] - 0s 33us/step - loss: 7.0022 - mean_absolute_percentage_error: 7.0022 - val_loss: 8.2192 - val_mean_absolute_percentage_error: 8.2192
# 7.575877303420962

# %%
# # Train Lasso Regression Model 

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LassoCV


from sklearn.model_selection import TimeSeriesSplit # you have everything done for you

# for time-series cross-validation set 5 folds 
tscv = TimeSeriesSplit(n_splits=5)

# Train Model
lasso = LassoCV(cv=tscv)
lasso.fit(x_train_c, y_train)


# Make forward prediction
lass_test = lasso.predict(x_test_c)
lasso_prediction = lasso.predict(x_pred_c)
MAP_error_lasso = mean_absolute_percentage_error(lass_test, y_test)

print('\n', 'mean_absolute_percentage_error', MAP_error_lasso, '\n')
# Out:
#  mean_absolute_percentage_error 2.475146044925282

# %%
# Visualize Results 

# Define Plot Makers

def plotModelResults(model, X_train=X_train, X_test=X_test, plot_intervals=False, plot_anomalies=False):
    """
        Plots modelled vs fact values, prediction intervals and anomalies
    
    """
    
    prediction = model.predict(X_test)
    
    plt.figure(figsize=(15, 7))
    plt.plot(prediction, "g", label="prediction", linewidth=2.0)
    plt.plot(y_test.values, label="actual", linewidth=2.0)
    
    if plot_intervals:
        cv = cross_val_score(model, X_train, y_train, 
                                    cv=tscv, 
                                    scoring="neg_mean_absolute_error")
        mae = cv.mean() * (-1)
        deviation = cv.std()
        
        scale = 1.96
        lower = prediction - (mae + scale * deviation)
        upper = prediction + (mae + scale * deviation)
        
        plt.plot(lower, "r--", label="upper bond / lower bond", alpha=0.5)
        plt.plot(upper, "r--", alpha=0.5)
        
        if plot_anomalies:
            anomalies = np.array([np.NaN]*len(y_test))
            anomalies[y_test<lower] = y_test[y_test<lower]
            anomalies[y_test>upper] = y_test[y_test>upper]
            plt.plot(anomalies, "o", markersize=10, label = "Anomalies")
    
    error = mean_absolute_percentage_error(prediction, y_test)
    plt.title("Mean absolute percentage error {0:.2f}%".format(error))
    plt.legend(loc="best")
    plt.tight_layout()
    plt.grid(True);
    
def plotCoefficients(model):
    """
        Plots sorted coefficient values of the model
    """
    
    coefs = pd.DataFrame(model.coef_, X_train.columns)
    coefs.columns = ["coef"]
    coefs["abs"] = coefs.coef.apply(np.abs)
    coefs = coefs.sort_values(by="abs", ascending=False).drop(["abs"], axis=1)
    
    plt.figure(figsize=(15, 7))
    coefs.coef.plot(kind='bar')
    plt.grid(True, axis='y')
    plt.hlines(y=0, xmin=0, xmax=10, linestyles='dashed')
    plt.xlim([-1, 10])
    plt.show();



# Call Plot makers
plotModelResults(lasso, 
                 X_train=x_train_c, 
                 X_test=x_test_c, 
                 plot_intervals=True, plot_anomalies=True)

plotCoefficients(lasso)

# %%
model_1_map = MAP_error1
model_2_map = MAP_error_lasso
model_3_map = MAP_error3


models_list = [model_1_map, model_2_map, model_3_map]
minIndex = models_list.index(min(models_list))
minIndex

models_output = np.array([list(tree1_prediction), 
                          list(lasso_prediction),
                          list(lstm_prediction)
                                 ])

model_names = np.array(['XGB', 'Lasso', 'LSTM'])


import csv 
import datetime
now = datetime.datetime.now()

prediction_date_vector = pred_date_END+timedelta(2)
prediction_date_vector = prediction_date_vector.strftime('%Y-%m-%d')


DATA = pd.DataFrame([prediction_date_vector]*24, columns = ['DATA'])

HOURS = pd.DataFrame(list(range(1,25)), columns = ['Hour'])

csvfile_top = pd.DataFrame(list(models_output[minIndex,:]), columns = ['Best:' +model_names[minIndex]])

csvfile_1 = pd.DataFrame(list(tree1_prediction), columns = ['XGB'])

csvfile_2 = pd.DataFrame(list(lasso_prediction), columns = ['Lasso'])

csvfile_3 = pd.DataFrame(list(lstm_prediction), columns = ['LSTM'])


cvfileall = pd.concat([DATA, HOURS, csvfile_top, csvfile_1, csvfile_2, csvfile_3], axis = 1)

test_date = pred_date_END+timedelta(1)
test_date = test_date.strftime('%Y%m%d')

prediction_date = pred_date_END+timedelta(2)
prediction_date = prediction_date.strftime('%Y%m%d')

cvfileall.to_excel('C:/Users/e351722/OneDrive - EDP/Competition/results/PBCCOMPRAS'+'_'+prediction_date+'.xlsx', sheet_name='sheet1', index=False)

# %%
plt.figure()
plt.scatter(model_names, models_list, marker = 'o', s = 100)
plt.ylabel('MAPE')
plt.title('COMPRAS Model Test Accuracy Comparison')


# Test vs Actual

models_test = np.array([list(predicted1), 
                          list(lass_test),
                          list(predictedkeras)
                                 ])

plt.figure(figsize=(10, 5))

plt.plot(combined, y_test1)
plt.plot(combined, list(models_test[minIndex,:]))
plt.legend(['Test Data',model_names[minIndex]])
plt.legend(['Test Data',model_names[minIndex]])
plt.title("Mean absolute percentage error {0:.2f}%".format(models_list[minIndex]))
plt.ylabel('Energy (MWh)')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')
